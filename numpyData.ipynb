# %% [markdown]
# <a href="https://colab.research.google.com/github/thmainagig/AssemblyScriptContract/blob/main/numpyData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy import misc
from PIL import Image
mystrey_array = np.array([[[0,1,2,3], [4,5,6,7]], [[7,86,6,98], [5,1,0,4]], [[5,36,32,48],[97,0,27,18]]])
mystrey_array.shape
mystrey_array[2,1][-1]
# mystrey_array[2,1]
mystrey_array[0:,0:,0]
a = np.arange(10,30)
a[-3:]
a[2:6]
a[12:]
a[a%2==0]
a1 = np.flip(a)
indices = np.nonzero(a)
indices
rng = np.random.default_rng()
r_a = rng.integers(4, size=(3,3,3))
r_a
x = np.linspace(0,100, num=9, dtype=np.int64)
y = np.linspace(-3,3, num=9, dtype=np.int64)
lin = plt.plot(x,y)
lin
noise = rng.integers(10000, size=(128,128,3))
no = plt.imshow(noise)
no
v1 = np.array([4,5,2,7])
v2 = np.array([2,1,3,3])
v1 + v2
v1 * 6
array_2d = np.array([[1,2,3,4], [5,6,7,8]])
array_2d * 5
a1 = np.array([[1,3],[0,1],[6,2],[9,7]])
b1=np.array([[4,1,3],[5,8,5]])
c = np.matmul(a1,b1)
c
img = misc.face()
plt.imshow(img)
img.shape
img.ndim
print(type(img))
grey_vals = np.array([0.2126,0.7152,0.0722])
RGB_array = img/255
# Y_linear = RGB_array @ grey_vals
Y_linear = np.matmul(RGB_array, grey_vals)
plt.imshow(np.rot90(255-Y_linear))
my_img = np.array(Image.open('/content/Compute with NumPy/yummy_macarons.jpg'))
plt.imshow(np.flip(255-my_img))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <ipython-input-99-eaa515883270>:39: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   img = misc.face()
# <class 'numpy.ndarray'>
